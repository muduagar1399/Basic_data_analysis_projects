# %% [markdown]
# ## Opencv project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Loading the iris dataset

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("dark")

# %% [markdown]
# ## Scatterplot

# %%
sns.lmplot(x='sepal_length', y='sepal_width', data=iris)

# %%
sns.lmplot(
    x='sepal_length',
    y='sepal_width',
    data=iris,
    fit_reg=False,  # No regression line
    hue='species'   # Color points by species
)

# %% [markdown]
# # boxplot

# %%
plt.figure(figsize=(10,8)) 
sns.boxplot(data=iris)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Removing Target Variable ---species

# %%
dataframe_1 = iris.drop(['species'], axis=1)
plt.figure(figsize=(10, 8))
sns.boxplot(data=dataframe_1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Color Platte

# %%
species_colors = ['#78C850',  # Setosa
                    '#F08030',  # Versicolor
                    '#6890F0',  # Verginica
                  ]

# %% [markdown]
# # Vilion plot

# %%
plt.figure(figsize=(10,8)) 
sns.violinplot( data=iris, 
               palette=species_colors) # Set color palette
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Swarm Plot

# %%
plt.figure(figsize=(10,8)) 
species_colors = {"setosa": "red", "versicolor": "blue", "virginica": "green"}
plt.figure(figsize=(10, 8))
sns.swarmplot(y='petal_length', x='species', data=iris, palette=species_colors)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# ## Combining plot

# %%
species_colors = {"setosa": "red", "versicolor": "blue", "virginica": "green"}

# Create the figure
plt.figure(figsize=(10, 8))

# Violin plot
sns.violinplot(
    x='species', 
    y='petal_length', 
    data=iris, 
    inner=None,  # Remove the bars inside the violins
    palette=species_colors
)

# Swarm plot
sns.swarmplot(
    x='species', 
    y='petal_length', 
    data=iris, 
    color='k',  # Make points black
    alpha=0.7   # Add slight transparency
)

# Set the title
plt.title('Combined Plot')

# Show the plot
plt.show()

# %% [markdown]
# ## Correlation

# %%
corr = iris.corr()

# %%
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(10, 8))
sns.histplot(data=iris, x='petal_length', kde=True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# ## Bar plot

# %%
species_colors = {"setosa": "red", "versicolor": "blue", "virginica": "green"}
plt.figure(figsize=(10, 8))
sns.countplot(x='species', data=iris, palette=species_colors)
plt.xticks(rotation=-45)
plt.title('Count Plot of Species')
plt.show()

# %% [markdown]
# ## catplot

# %%
g=sns.catplot(
    x='species', 
    y='petal_width', 
    data=iris, 
    hue='species',  # Color by species
    kind='swarm'    # Swarmplot
)
g.set_xticklabels(rotation=-45)

# Set the title
g.fig.suptitle('Swarmplot of Petal Width by Species', y=1.02)

# Show the plot
plt.show()
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Density Plot

# %%
plt.figure(figsize=(10, 8))
sns.kdeplot(
    x='sepal_length', 
    y='sepal_width', 
    data=iris, 
    fill=True 
)

plt.title('KDE Plot of Sepal Length vs Sepal Width')
plt.show()

# %% [markdown]
# ## Joint Distribution Plot

# %%
sns.jointplot(x='petal_length', y='petal_width', data=iris)
plt.show()
